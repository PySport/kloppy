# %% [markdown]
# # StatsPerform
#
# ## Load local event files

# %%
from kloppy import statsperform

dataset = statsperform.load_event(
    ma1_data="../../kloppy/tests/files/statsperform_event_ma1.json",
    ma3_data="../../kloppy/tests/files/statsperform_event_ma3.json",
    
    # Optional arguments
    coordinates="statsperform"
)

dataset.to_df().head()
# Out:
#      event_id    event_type    result success  period_id  \
# 0  2328589789          PASS  COMPLETE    True          1
# 1  2328589863          PASS  COMPLETE    True          1
# 2  2328589885          PASS  COMPLETE    True          1
# 3  2328589929          PASS  COMPLETE    True          1
# 4  2328589997  GENERIC:foul      None    None          1
#
#                timestamp end_timestamp ball_state           ball_owning_team  \
# 0 0 days 00:00:00.030000          None      alive  75xi6hloabmnjn2kzgj1g8h1s
# 1 0 days 00:00:02.075000          None      alive  75xi6hloabmnjn2kzgj1g8h1s
# 2 0 days 00:00:06.803000          None      alive  75xi6hloabmnjn2kzgj1g8h1s
# 3 0 days 00:00:09.373000          None      alive  75xi6hloabmnjn2kzgj1g8h1s
# 4 0 days 00:00:11.695000          None      alive  75xi6hloabmnjn2kzgj1g8h1s
#
#                      team_id  ... end_coordinates_x  end_coordinates_y  \
# 0  75xi6hloabmnjn2kzgj1g8h1s  ...         33.670365          51.121324
# 1  75xi6hloabmnjn2kzgj1g8h1s  ...         33.777624          89.003624
# 2  75xi6hloabmnjn2kzgj1g8h1s  ...         55.906349          92.958461
# 3  75xi6hloabmnjn2kzgj1g8h1s  ...         48.063492          96.720379
# 4  75xi6hloabmnjn2kzgj1g8h1s  ...               NaN                NaN
#
#    receiver_player_id  set_piece_type     pass_type body_part_type  \
# 0                None        KICK_OFF          None           None
# 1                None            None          None           None
# 2                None            None  CHIPPED_PASS           None
# 3                None            None          None           None
# 4                None            None          None           None
#
#   goalkeeper_type duel_type card_type is_counter_attack
# 0            None      None      None              None
# 1            None      None      None              None
# 2            None      None      None              None
# 3            None      None      None              None
# 4            None      None      None              None
#
# [5 rows x 23 columns]

# %%
from kloppy import statsperform

dataset = statsperform.load_event(
    ma1_data="../../kloppy/tests/files/statsperform_event_ma1.xml",
    ma3_data="../../kloppy/tests/files/statsperform_event_ma3.xml",
    
    # Optional arguments
    coordinates="statsperform"
)

dataset.to_df().head()
# Out:
#      event_id    event_type    result success  period_id  \
# 0  2328589789          PASS  COMPLETE    True          1
# 1  2328589863          PASS  COMPLETE    True          1
# 2  2328589885          PASS  COMPLETE    True          1
# 3  2328589929          PASS  COMPLETE    True          1
# 4  2328589997  GENERIC:foul      None    None          1
#
#                timestamp end_timestamp ball_state           ball_owning_team  \
# 0 0 days 00:00:00.030000          None      alive  75xi6hloabmnjn2kzgj1g8h1s
# 1 0 days 00:00:02.075000          None      alive  75xi6hloabmnjn2kzgj1g8h1s
# 2 0 days 00:00:06.803000          None      alive  75xi6hloabmnjn2kzgj1g8h1s
# 3 0 days 00:00:09.373000          None      alive  75xi6hloabmnjn2kzgj1g8h1s
# 4 0 days 00:00:11.695000          None      alive  75xi6hloabmnjn2kzgj1g8h1s
#
#                      team_id  ... end_coordinates_x  end_coordinates_y  \
# 0  75xi6hloabmnjn2kzgj1g8h1s  ...         33.670365          51.121324
# 1  75xi6hloabmnjn2kzgj1g8h1s  ...         33.777624          89.003624
# 2  75xi6hloabmnjn2kzgj1g8h1s  ...         55.906349          92.958461
# 3  75xi6hloabmnjn2kzgj1g8h1s  ...         48.063492          96.720379
# 4  75xi6hloabmnjn2kzgj1g8h1s  ...               NaN                NaN
#
#    receiver_player_id  set_piece_type     pass_type body_part_type  \
# 0                None        KICK_OFF          None           None
# 1                None            None          None           None
# 2                None            None  CHIPPED_PASS           None
# 3                None            None          None           None
# 4                None            None          None           None
#
#   goalkeeper_type duel_type card_type is_counter_attack
# 0            None      None      None              None
# 1            None      None      None              None
# 2            None      None      None              None
# 3            None      None      None              None
# 4            None      None      None              None
#
# [5 rows x 23 columns]

# %% [markdown]
# ## Load local tracking files

# %%
from kloppy import statsperform

dataset = statsperform.load_tracking(
    ma1_data="../../kloppy/tests/files/statsperform_tracking_ma1.json",
    ma25_data="../../kloppy/tests/files/statsperform_tracking_ma25.txt",

    # Optional arguments
    coordinates="statsperform"
)

dataset.to_df().head()
# Out:
#    period_id              timestamp       frame_id ball_state  \
# 0          1        0 days 00:00:00  1598184000000      alive
# 1          1 0 days 00:00:00.100000  1598184000100      alive
# 2          1 0 days 00:00:00.200000  1598184000200      alive
# 3          1 0 days 00:00:00.300000  1598184000300      alive
# 4          1 0 days 00:00:00.400000  1598184000400      alive
#
#   ball_owning_team_id  ball_x  ball_y  ball_z ball_speed  \
# 0                None  52.350  33.250     0.0       None
# 1                None  50.615  35.325     0.0       None
# 2                None  49.630  36.140     0.0       None
# 3                None  48.725  36.625     0.0       None
# 4                None  47.890  37.130     0.0       None
#
#    a2s2c6anax9wnlsw1s6vunl5h_x  ...  6wfwy94p5bm0zv3aku0urfq39_d  \
# 0                       52.803  ...                         None
# 1                       52.558  ...                         None
# 2                       52.310  ...                         None
# 3                       52.059  ...                         None
# 4                       51.804  ...                         None
#
#   6wfwy94p5bm0zv3aku0urfq39_s 6ekdnbnk56xlxforb5owt3dn9_x  \
# 0                        None                       5.268
# 1                        None                       5.265
# 2                        None                       5.264
# 3                        None                       5.268
# 4                        None                       5.277
#
#    6ekdnbnk56xlxforb5owt3dn9_y  6ekdnbnk56xlxforb5owt3dn9_d  \
# 0                       33.556                         None
# 1                       33.529                         None
# 2                       33.502                         None
# 3                       33.476                         None
# 4                       33.452                         None
#
#   6ekdnbnk56xlxforb5owt3dn9_s ct32113pfx5q9avf2c0x208ru_x  \
# 0                        None                         NaN
# 1                        None                         NaN
# 2                        None                         NaN
# 3                        None                         NaN
# 4                        None                         NaN
#
#    ct32113pfx5q9avf2c0x208ru_y  ct32113pfx5q9avf2c0x208ru_d  \
# 0                          NaN                         None
# 1                          NaN                         None
# 2                          NaN                         None
# 3                          NaN                         None
# 4                          NaN                         None
#
#   ct32113pfx5q9avf2c0x208ru_s
# 0                        None
# 1                        None
# 2                        None
# 3                        None
# 4                        None
#
# [5 rows x 101 columns]

# %%
from kloppy import statsperform

dataset = statsperform.load_tracking(
    ma1_data="../../kloppy/tests/files/statsperform_tracking_ma1.xml",
    ma25_data="../../kloppy/tests/files/statsperform_tracking_ma25.txt",

    # Optional arguments
    coordinates="statsperform"
)

dataset.to_df().head()
# Out:
#    period_id              timestamp       frame_id ball_state  \
# 0          1        0 days 00:00:00  1598184000000      alive
# 1          1 0 days 00:00:00.100000  1598184000100      alive
# 2          1 0 days 00:00:00.200000  1598184000200      alive
# 3          1 0 days 00:00:00.300000  1598184000300      alive
# 4          1 0 days 00:00:00.400000  1598184000400      alive
#
#   ball_owning_team_id  ball_x  ball_y  ball_z ball_speed  \
# 0                None  52.350  33.250     0.0       None
# 1                None  50.615  35.325     0.0       None
# 2                None  49.630  36.140     0.0       None
# 3                None  48.725  36.625     0.0       None
# 4                None  47.890  37.130     0.0       None
#
#    a2s2c6anax9wnlsw1s6vunl5h_x  ...  6wfwy94p5bm0zv3aku0urfq39_d  \
# 0                       52.803  ...                         None
# 1                       52.558  ...                         None
# 2                       52.310  ...                         None
# 3                       52.059  ...                         None
# 4                       51.804  ...                         None
#
#   6wfwy94p5bm0zv3aku0urfq39_s 6ekdnbnk56xlxforb5owt3dn9_x  \
# 0                        None                       5.268
# 1                        None                       5.265
# 2                        None                       5.264
# 3                        None                       5.268
# 4                        None                       5.277
#
#    6ekdnbnk56xlxforb5owt3dn9_y  6ekdnbnk56xlxforb5owt3dn9_d  \
# 0                       33.556                         None
# 1                       33.529                         None
# 2                       33.502                         None
# 3                       33.476                         None
# 4                       33.452                         None
#
#   6ekdnbnk56xlxforb5owt3dn9_s ct32113pfx5q9avf2c0x208ru_x  \
# 0                        None                         NaN
# 1                        None                         NaN
# 2                        None                         NaN
# 3                        None                         NaN
# 4                        None                         NaN
#
#    ct32113pfx5q9avf2c0x208ru_y  ct32113pfx5q9avf2c0x208ru_d  \
# 0                          NaN                         None
# 1                          NaN                         None
# 2                          NaN                         None
# 3                          NaN                         None
# 4                          NaN                         None
#
#   ct32113pfx5q9avf2c0x208ru_s
# 0                        None
# 1                        None
# 2                        None
# 3                        None
# 4                        None
#
# [5 rows x 101 columns]
